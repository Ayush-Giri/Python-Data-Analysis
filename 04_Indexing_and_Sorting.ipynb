# %%
import pandas as pd

# %%
bitcoin_dataframe = pd.read_csv("1.section data/coin_Bitcoin.csv")

# %%
bitcoin_dataframe
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
date_index_dataframe = bitcoin_dataframe.set_index(keys="Date")
date_index_dataframe
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
happiness_dataframe = pd.read_csv("1.section data/world-happiness-report-2021.csv")

# %%
happiness_dataframe
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
happiness_dataframe.set_index(keys="Country name", inplace= True)

# %%
happiness_dataframe
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
print(happiness_dataframe.columns)
# Out:
# Index(['Regional indicator', 'Ladder score', 'Standard error of ladder score',
#        'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
happiness_dataframe["Healthy life expectancy"]
# Out:
# Country name
# Finland        72.000
# Denmark        72.700
# Switzerland    74.400
# Iceland        73.000
# Netherlands    72.400
#                 ...
# Lesotho        48.700
# Botswana       59.269
# Rwanda         61.400
# Zimbabwe       56.201
# Afghanistan    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
print(happiness_dataframe.columns)
# Out:
# Index(['Regional indicator', 'Ladder score', 'Standard error of ladder score',
#        'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
happiness_dataframe.sort_values(by='Healthy life expectancy', ascending=False)
# Out:
#                            Regional indicator  Ladder score  \
# Country name
# Singapore                      Southeast Asia         6.377
# Hong Kong S.A.R. of China           East Asia         5.477
# Japan                               East Asia         5.940
# Spain                          Western Europe         6.491
# Switzerland                    Western Europe         7.571
# ...                                       ...           ...
# Swaziland                  Sub-Saharan Africa         4.308
# Ivory Coast                Sub-Saharan Africa         5.306
# Nigeria                    Sub-Saharan Africa         4.759
# Lesotho                    Sub-Saharan Africa         3.512
# Chad                       Sub-Saharan Africa         4.355
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Singapore                                           0.043         6.460
# ...

# %%
#sorting by multiple values

# %%
house_dataframe = pd.read_csv("1.section data/kc_house_data.csv")

# %%
house_dataframe
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
house_dataframe.sort_values(by="price", ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# ...

# %%
house_dataframe.sort_values(by="bedrooms", ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# ...           ...              ...        ...       ...        ...
# 19452  3980300371  20140926T000000   142000.0         0       0.00
# 8484   2310060040  20140925T000000   240000.0         0       2.50
# 875    6306400140  20140612T000000  1095000.0         0       0.00
# 8477   2569500210  20141117T000000   339950.0         0       2.50
# 9773   3374500520  20150429T000000   355000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# ...

# %%
house_dataframe.sort_values(by=["bedrooms", "bathrooms"], ascending=False)
#This means first sort by bedrooms and if there is a tie then sort the tied rows with the number of bathrooms
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# ...           ...              ...        ...       ...        ...
# 6994   2954400190  20140624T000000  1295650.0         0       0.00
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 14423  9543000205  20150413T000000   139950.0         0       0.00
# 19452  3980300371  20140926T000000   142000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# ...

# %%
happiness_dataframe.sort_index()
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %%
titanic_dataframe = pd.read_csv("1.section data/titanic.csv")

# %%
titanic_dataframe
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic_dataframe["pclass"].value_counts().sort_values().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
titanic_dataframe["pclass"].value_counts().sort_index().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
house_dataframe["bedrooms"].value_counts().sort_values().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
house_dataframe["bedrooms"].value_counts().sort_index().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
happiness_dataframe.loc["Yemen"]
# Out:
# Regional indicator                            Middle East and North Africa
# Ladder score                                                         3.658
# Standard error of ladder score                                        0.07
# upperwhisker                                                         3.794
# lowerwhisker                                                         3.521
# Logged GDP per capita                                                7.578
# Social support                                                       0.832
# Healthy life expectancy                                             57.122
# Freedom to make life choices                                         0.602
# Generosity                                                          -0.147
# Perceptions of corruption                                              0.8
# Ladder score in Dystopia                                              2.43
# ...

# %%
happiness_dataframe.loc[["Nepal"]]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Nepal                South Asia         5.269                            0.07
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Nepal                5.406         5.132                   8.12
#
#               Social support  Healthy life expectancy  \
# Country name
# Nepal                  0.774                   64.233
#
#               Freedom to make life choices  Generosity  \
# Country name
# Nepal                                0.782       0.152
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# Nepal                             0.727                      2.43
#
#               Explained by: Log GDP per capita  Explained by: Social support  \
# Country name
# Nepal                                    0.519                         0.702
#
#               Explained by: Healthy life expectancy  \
# ...

# %%
happiness_dataframe.loc[["Nepal", "India", "Bangladesh"]]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Nepal                South Asia         5.269                           0.070
# India                South Asia         3.819                           0.026
# Bangladesh           South Asia         5.025                           0.046
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Nepal                5.406         5.132                  8.120
# India                3.869         3.769                  8.755
# Bangladesh           5.115         4.934                  8.454
#
#               Social support  Healthy life expectancy  \
# Country name
# Nepal                  0.774                   64.233
# India                  0.603                   60.633
# Bangladesh             0.693                   64.800
#
#               Freedom to make life choices  Generosity  \
# Country name
# Nepal                                0.782       0.152
# ...

# %%
happiness_dataframe.sort_index(inplace=True)

# %%
happiness_dataframe
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %%
happiness_dataframe.loc["India": "Nepal"]
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# India                                 South Asia         3.819
# Indonesia                         Southeast Asia         5.345
# Iran                Middle East and North Africa         4.721
# Iraq                Middle East and North Africa         4.854
# Ireland                           Western Europe         7.085
# Israel              Middle East and North Africa         7.157
# Italy                             Western Europe         6.483
# Ivory Coast                   Sub-Saharan Africa         5.306
# Jamaica              Latin America and Caribbean         6.309
# Japan                                  East Asia         5.940
# Jordan              Middle East and North Africa         4.395
# Kazakhstan    Commonwealth of Independent States         6.152
# Kenya                         Sub-Saharan Africa         4.607
# Kosovo                Central and Eastern Europe         6.372
# ...

# %%
happiness_dataframe
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %%
happiness_dataframe.iloc[0]
# Out:
# Regional indicator                            South Asia
# Ladder score                                       2.523
# Standard error of ladder score                     0.038
# upperwhisker                                       2.596
# lowerwhisker                                       2.449
# Logged GDP per capita                              7.695
# Social support                                     0.463
# Healthy life expectancy                           52.493
# Freedom to make life choices                       0.382
# Generosity                                        -0.102
# Perceptions of corruption                          0.924
# Ladder score in Dystopia                            2.43
# Explained by: Log GDP per capita                    0.37
# Explained by: Social support                         0.0
# Explained by: Healthy life expectancy              0.126
# Explained by: Freedom to make life choices           0.0
# ...

# %%
happiness_dataframe.iloc[[0,3,5]]
# Out:
#                        Regional indicator  Ladder score  \
# Country name
# Afghanistan                    South Asia         2.523
# Argentina     Latin America and Caribbean         5.929
# Australia           North America and ANZ         7.183
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Argentina                              0.056         6.040         5.819
# Australia                              0.041         7.265         7.102
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Afghanistan                   7.695           0.463                   52.493
# Argentina                     9.962           0.898                   69.000
# Australia                    10.796           0.940                   73.900
#
#               Freedom to make life choices  Generosity  \
# Country name
# ...

# %%
happiness_dataframe.iloc[0:3]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Afghanistan                     South Asia         2.523
# Albania         Central and Eastern Europe         5.117
# Algeria       Middle East and North Africa         4.887
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Albania                                0.059         5.234         5.001
# Algeria                                0.053         4.991         4.783
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Afghanistan                   7.695           0.463                   52.493
# Albania                       9.520           0.697                   68.999
# Algeria                       9.342           0.802                   66.005
#
#               Freedom to make life choices  Generosity  \
# Country name
# ...

# %%
titanic_dataframe
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic_dataframe.iloc[0:15][["name", "sex"]]
# Out:
#                                                  name     sex
# 0                       Allen, Miss. Elisabeth Walton  female
# 1                      Allison, Master. Hudson Trevor    male
# 2                        Allison, Miss. Helen Loraine  female
# 3                Allison, Mr. Hudson Joshua Creighton    male
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5                                 Anderson, Mr. Harry    male
# 6                   Andrews, Miss. Kornelia Theodosia  female
# 7                              Andrews, Mr. Thomas Jr    male
# 8       Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9                             Artagaveytia, Mr. Ramon    male
# 10                             Astor, Col. John Jacob    male
# 11  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female
# 12                      Aubart, Mme. Leontine Pauline  female
# 13                       Barber, Miss. Ellen 'Nellie'  female
# ...

# %%
pokemon_dataframe = pd.read_csv(filepath_or_buffer="1.section data/Pokemon.csv")

# %%
pokemon_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Num        151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
#  4   Total      151 non-null    int64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    int64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 14.4+ KB

# %%
pokemon_dataframe.set_index(keys="Name", inplace=True)

# %%
pokemon_dataframe
# Out:
#             Num   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur     1    Grass  Poison    318   45      49       49       65
# Ivysaur       2    Grass  Poison    405   60      62       63       80
# Venusaur      3    Grass  Poison    525   80      82       83      100
# Charmander    4     Fire     NaN    309   39      52       43       60
# Charmeleon    5     Fire     NaN    405   58      64       58       80
# ...         ...      ...     ...    ...  ...     ...      ...      ...
# Dratini     147   Dragon     NaN    300   41      64       45       50
# Dragonair   148   Dragon     NaN    420   61      84       65       70
# Dragonite   149   Dragon  Flying    600   91     134       95      100
# Mewtwo      150  Psychic     NaN    680  106     110       90      154
# Mew         151  Psychic     NaN    600  100     100      100      100
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# Bulbasaur        65     45      1      False
# ...

# %%
pokemon_dataframe.sort_values(by="Attack", ascending=False)
# Out:
#            Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Dragonite  149    Dragon  Flying    600   91     134       95      100
# Rhydon     112    Ground    Rock    485  105     130      120       45
# Flareon    136      Fire     NaN    525   65     130       60       95
# Machamp     68  Fighting     NaN    505   90     130       80       65
# Kingler     99     Water     NaN    475   55     130      115       50
# ...        ...       ...     ...    ...  ...     ...      ...      ...
# Kakuna      14       Bug  Poison    205   45      25       50       25
# Abra        63   Psychic     NaN    310   25      20       15      105
# Metapod     11       Bug     NaN    205   50      20       55       25
# Magikarp   129     Water     NaN    200   20      10       55       15
# Chansey    113    Normal     NaN    450  250       5        5       35
#
#            Sp. Def  Speed  Stage  Legendary
# Name
# Dragonite      100     80      3      False
# ...

# %%
pokemon_dataframe.sort_values(by="Num", inplace=True)

# %%
pokemon_dataframe
# Out:
#             Num   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur     1    Grass  Poison    318   45      49       49       65
# Ivysaur       2    Grass  Poison    405   60      62       63       80
# Venusaur      3    Grass  Poison    525   80      82       83      100
# Charmander    4     Fire     NaN    309   39      52       43       60
# Charmeleon    5     Fire     NaN    405   58      64       58       80
# ...         ...      ...     ...    ...  ...     ...      ...      ...
# Dratini     147   Dragon     NaN    300   41      64       45       50
# Dragonair   148   Dragon     NaN    420   61      84       65       70
# Dragonite   149   Dragon  Flying    600   91     134       95      100
# Mewtwo      150  Psychic     NaN    680  106     110       90      154
# Mew         151  Psychic     NaN    600  100     100      100      100
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# Bulbasaur        65     45      1      False
# ...

# %%
pokemon_dataframe.sort_values(by=["Total", "Attack"], ascending=False)
# Out:
#            Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Mewtwo     150   Psychic     NaN    680  106     110       90      154
# Dragonite  149    Dragon  Flying    600   91     134       95      100
# Mew        151   Psychic     NaN    600  100     100      100      100
# Moltres    146      Fire  Flying    580   90     100       90      125
# Zapdos     145  Electric  Flying    580   90      90       85      125
# ...        ...       ...     ...    ...  ...     ...      ...      ...
# Kakuna      14       Bug  Poison    205   45      25       50       25
# Metapod     11       Bug     NaN    205   50      20       55       25
# Magikarp   129     Water     NaN    200   20      10       55       15
# Weedle      13       Bug  Poison    195   40      35       30       20
# Caterpie    10       Bug     NaN    195   45      30       35       20
#
#            Sp. Def  Speed  Stage  Legendary
# Name
# Mewtwo          90    130      1       True
# ...

# %%
pokemon_dataframe.sort_index(inplace=True)

# %%
pokemon_dataframe
# Out:
#             Num    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Abra         63   Psychic     NaN    310   25      20       15      105
# Aerodactyl  142      Rock  Flying    515   80     105       65       60
# Alakazam     65   Psychic     NaN    500   55      50       45      135
# Arbok        24    Poison     NaN    438   60      85       69       65
# Arcanine     59      Fire     NaN    555   90     110       80      100
# ...         ...       ...     ...    ...  ...     ...      ...      ...
# Weepinbell   70     Grass  Poison    390   65      90       50       85
# Weezing     110    Poison     NaN    490   65      90      120       85
# Wigglytuff   40    Normal   Fairy    435  140      70       45       85
# Zapdos      145  Electric  Flying    580   90      90       85      125
# Zubat        41    Poison  Flying    245   40      45       35       30
#
#             Sp. Def  Speed  Stage  Legendary
# Name
# ...

# %%
pokemon_dataframe["Speed"].sort_values(ascending=False).head(n=10).mean()
# Out:
# 122.0

# %%
pokemon_dataframe[["Attack", "Type 1"]].sort_values("Attack", ascending=False).head(n=20)["Type 1"].value_counts()
# Out:
# Fighting    4
# Water       3
# Rock        3
# Fire        2
# Bug         2
# Normal      2
# Dragon      1
# Ground      1
# Psychic     1
# Poison      1
# Name: Type 1, dtype: int64

# %%
pokemon_dataframe.loc[["Diglett"]]
# Out:
#          Num  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Diglett   50  Ground    NaN    265  10      55       25       35       45
#
#          Speed  Stage  Legendary
# Name
# Diglett     95      1      False

# %%
pokemon_dataframe.loc[["Eevee", "Vulpix"]]
# Out:
#         Num  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Eevee   133  Normal    NaN    325  55      55       50       45       65
# Vulpix   37    Fire    NaN    299  38      41       40       50       65
#
#         Speed  Stage  Legendary
# Name
# Eevee      55      1      False
# Vulpix     65      1      False

# %%
pokemon_dataframe["Charizard":"Charmeleon"]
# Out:
#             Num Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Charizard     6   Fire  Flying    534  78      84       78      109       85
# Charmander    4   Fire     NaN    309  39      52       43       60       50
# Charmeleon    5   Fire     NaN    405  58      64       58       80       65
#
#             Speed  Stage  Legendary
# Name
# Charizard     100      3      False
# Charmander     65      1      False
# Charmeleon     80      2      False

# %%
pokemon_dataframe.iloc[[30, 40, 50]]
# Out:
#           Num  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Eevee     133  Normal     NaN    325  55      55       50       45       65
# Gengar     94   Ghost  Poison    500  60      65       60      130       75
# Gyarados  130   Water  Flying    540  95     125       79       60      100
#
#           Speed  Stage  Legendary
# Name
# Eevee        55      1      False
# Gengar      110      3      False
# Gyarados     81      2      False

# %%
pokemon_dataframe.loc[["Magikarp", "Goldeen", "Horsea", "Seaking", "Seadra", "Gyarados"]]
# Out:
#           Num Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Magikarp  129  Water     NaN    200  20      10       55       15       20
# Goldeen   118  Water     NaN    320  45      67       60       35       50
# Horsea    116  Water     NaN    295  30      40       70       70       25
# Seaking   119  Water     NaN    450  80      92       65       65       80
# Seadra    117  Water     NaN    440  55      65       95       95       45
# Gyarados  130  Water  Flying    540  95     125       79       60      100
#
#           Speed  Stage  Legendary
# Name
# Magikarp     80      1      False
# Goldeen      63      1      False
# Horsea       60      1      False
# Seaking      68      2      False
# Seadra       85      2      False
# Gyarados     81      2      False

# %%
fish_like_pokemon_dataframe = pokemon_dataframe.loc[["Magikarp", "Goldeen", "Horsea", "Seaking", "Seadra", "Gyarados"]]\
.sort_values(by="Attack")

# %%
fish_like_pokemon_dataframe
# Out:
#           Num Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Magikarp  129  Water     NaN    200  20      10       55       15       20
# Horsea    116  Water     NaN    295  30      40       70       70       25
# Seadra    117  Water     NaN    440  55      65       95       95       45
# Goldeen   118  Water     NaN    320  45      67       60       35       50
# Seaking   119  Water     NaN    450  80      92       65       65       80
# Gyarados  130  Water  Flying    540  95     125       79       60      100
#
#           Speed  Stage  Legendary
# Name
# Magikarp     80      1      False
# Horsea       60      1      False
# Seadra       85      2      False
# Goldeen      63      1      False
# Seaking      68      2      False
# Gyarados     81      2      False

# %%
fish_like_pokemon_dataframe["Attack"].sort_values().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Name'>
