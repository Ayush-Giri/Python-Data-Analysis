# %%
import pandas as pd
house_dataframe = pd.read_csv("1.section data/kc_house_data.csv")
titanic_dataframe = pd.read_csv("1.section data/titanic.csv")
netflix_dataframe = pd.read_csv("1.section data/netflix_titles.csv", sep="|", index_col=0)

# %%
titanic_dataframe.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
# Retrieving a particular column
titanic_name_column = titanic_dataframe["name"]
print(titanic_name_column)
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
print(type(titanic_name_column))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(titanic_dataframe["age"])
# Out:
# 0           29
# 1       0.9167
# 2            2
# 3           30
# 4           25
#          ...
# 1304      14.5
# 1305         ?
# 1306      26.5
# 1307        27
# 1308        29
# Name: age, Length: 1309, dtype: object

# %%
titanic_names = titanic_dataframe["name"]
print(titanic_names)
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
house_dataframe
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
total_price = house_dataframe["price"].sum()
print(total_price)
# Out:
# 11672925008.0

# %%
minimum_house_price = house_dataframe["price"].min()
print(minimum_house_price)
# Out:
# 75000.0

# %%
maximum_house_price = house_dataframe["price"].max()
print(maximum_house_price)
# Out:
# 7700000.0

# %%
titanic_name_column.head()
# Out:
# 0                      Allen, Miss. Elisabeth Walton
# 1                     Allison, Master. Hudson Trevor
# 2                       Allison, Miss. Helen Loraine
# 3               Allison, Mr. Hudson Joshua Creighton
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# Name: name, dtype: object

# %%
titanic_name_column.tail(n=10)
# Out:
# 1299                        Yasbeck, Mr. Antoni
# 1300    Yasbeck, Mrs. Antoni (Selini Alexander)
# 1301                       Youseff, Mr. Gerious
# 1302                          Yousif, Mr. Wazli
# 1303                      Yousseff, Mr. Gerious
# 1304                       Zabour, Miss. Hileni
# 1305                      Zabour, Miss. Thamine
# 1306                  Zakarian, Mr. Mapriededer
# 1307                        Zakarian, Mr. Ortin
# 1308                         Zimmerman, Mr. Leo
# Name: name, dtype: object

# %%
print(titanic_name_column.values)
# Out:
# ['Allen, Miss. Elisabeth Walton' 'Allison, Master. Hudson Trevor'
#  'Allison, Miss. Helen Loraine' ... 'Zakarian, Mr. Mapriededer'
#  'Zakarian, Mr. Ortin' 'Zimmerman, Mr. Leo']

# %%
print(titanic_name_column.index)
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
house_dataframe
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
house_price_column = house_dataframe["price"]
print(house_price_column.describe())
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
netflix_dataframe
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_rating_column = netflix_dataframe["rating"]
print(netflix_rating_column)
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
print(netflix_rating_column.describe())
# Out:
# count      8803
# unique       17
# top       TV-MA
# freq       3207
# Name: rating, dtype: object

# %%
netflix_dataframe.describe(include=["object", "int64", "float64"])
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
netflix_release_years = netflix_dataframe["release_year"]
netflix_release_years.describe()
# Out:
# count    8807.000000
# mean     2014.180198
# std         8.819312
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
print(house_dataframe.columns)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
print(house_dataframe["bedrooms"].unique())
# Out:
# [ 3  2  4  5  1  6  7  0  8  9 11 10 33]

# %%
netflix_dataframe
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print(netflix_dataframe["rating"].unique())
# Out:
# ['PG-13' 'TV-MA' 'PG' 'TV-14' 'TV-PG' 'TV-Y' 'TV-Y7' 'R' 'TV-G' 'G'
#  'NC-17' '74 min' '84 min' '66 min' 'NR' nan 'TV-Y7-FV' 'UR']

# %%
print(netflix_dataframe["rating"].nunique(dropna = False))
# Out:
# 18

# %%
house_dataframe
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
print(house_dataframe["zipcode"].unique())
# Out:
# [98178 98125 98028 98136 98074 98053 98003 98198 98146 98038 98007 98115
#  98107 98126 98019 98103 98002 98133 98040 98092 98030 98119 98112 98052
#  98027 98117 98058 98001 98056 98166 98023 98070 98148 98105 98042 98008
#  98059 98122 98144 98004 98005 98034 98075 98116 98010 98118 98199 98032
#  98045 98102 98077 98108 98168 98177 98065 98029 98006 98109 98022 98033
#  98155 98024 98011 98031 98106 98072 98188 98014 98055 98039]

# %%
print(house_dataframe["zipcode"].nunique())
# Out:
# 70

# %%
house_dataframe["price"]
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
print(house_dataframe["price"].nlargest())
# Out:
# 7252    7700000.0
# 3914    7062500.0
# 9254    6885000.0
# 4411    5570000.0
# 1448    5350000.0
# Name: price, dtype: float64

# %%
print(house_dataframe["price"].nsmallest())
# Out:
# 1149     75000.0
# 15293    78000.0
# 465      80000.0
# 16198    81000.0
# 8274     82000.0
# Name: price, dtype: float64

# %%
house_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
house_dataframe.nlargest(10, ["price"])
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
house_dataframe.nlargest(n=10, columns=["bedrooms"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 4235   2902200015  20150106T000000   700000.0         9       3.00
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
house_dataframe.nsmallest(10, ["sqft_lot15"])
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 19669  7899800863  20141001T000000  299900.0         3       2.50
# 20749  2827100075  20140727T000000  286308.0         2       1.50
# 513    2827100070  20141105T000000  290000.0         4       1.00
# 20907  8562780540  20141222T000000  325000.0         2       2.25
# 21015  8562780530  20150328T000000  338500.0         2       2.25
# 19727  8562780160  20150329T000000  334950.0         2       2.25
# 20731  8562780200  20150427T000000  352499.0         2       2.25
# 21109  8562780190  20141007T000000  315000.0         2       2.25
# 21536  8562780180  20140612T000000  336750.0         2       2.25
# 20095  8562780490  20150223T000000  335000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 19669         1210      2046     2.0           0     0  ...      9
# 20749         1220      1036     3.0           0     0  ...      7
# ...

# %%
#Getting multiple columns
print(netflix_dataframe.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix_dataframe[["title", "director", "rating"]]
# Out:
#                       title         director rating
# 0      Dick Johnson Is Dead  Kirsten Johnson  PG-13
# 1             Blood & Water              NaN  TV-MA
# 2                 Ganglands  Julien Leclercq  TV-MA
# 3     Jailbirds New Orleans              NaN  TV-MA
# 4              Kota Factory              NaN  TV-MA
# ...                     ...              ...    ...
# 8802                 Zodiac    David Fincher      R
# 8803            Zombie Dumb              NaN  TV-Y7
# 8804             Zombieland  Ruben Fleischer      R
# 8805                   Zoom     Peter Hewitt     PG
# 8806                 Zubaan      Mozez Singh  TV-14
#
# [8807 rows x 3 columns]

# %%
house_dataframe[["price", "bedrooms", "bathrooms"]]
# Out:
#           price  bedrooms  bathrooms
# 0      221900.0         3       1.00
# 1      538000.0         3       2.25
# 2      180000.0         2       1.00
# 3      604000.0         4       3.00
# 4      510000.0         3       2.00
# ...         ...       ...        ...
# 21608  360000.0         3       2.50
# 21609  400000.0         4       2.50
# 21610  402101.0         2       0.75
# 21611  400000.0         3       2.50
# 21612  325000.0         2       0.75
#
# [21613 rows x 3 columns]

# %%
house_dataframe["bedrooms"]
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
house_dataframe["bedrooms"].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
titanic_dataframe["sex"]
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
titanic_dataframe["sex"].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
print(titanic_dataframe.columns)
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
titanic_dataframe["pclass"].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: pclass, dtype: int64

# %%
netflix_dataframe.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix_dataframe["director"].value_counts()
# Out:
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: director, Length: 4528, dtype: int64

# %%
netflix_dataframe["director"].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
house_dataframe.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
house_dataframe["floors"].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
house_dataframe[["bedrooms", "bathrooms"]]
# Out:
#        bedrooms  bathrooms
# 0             3       1.00
# 1             3       2.25
# 2             2       1.00
# 3             4       3.00
# 4             3       2.00
# ...         ...        ...
# 21608         3       2.50
# 21609         4       2.50
# 21610         2       0.75
# 21611         3       2.50
# 21612         2       0.75
#
# [21613 rows x 2 columns]

# %%
house_dataframe[["bedrooms", "bathrooms"]].value_counts()
# Out:
# bedrooms  bathrooms
# 4         2.50         2502
# 3         2.50         2357
#           1.75         1870
#           1.00         1780
# 2         1.00         1558
#                        ...
# 7         1.00            1
#           3.25            1
#           5.50            1
#           5.75            1
# 33        1.75            1
# Length: 144, dtype: int64

# %%
house_dataframe["bedrooms"].plot()
# Out:
# <AxesSubplot:>

# %%
house_dataframe["bedrooms"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
house_dataframe["bedrooms"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='bedrooms'>

# %%
print(titanic_dataframe.columns)
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
titanic_dataframe["survived"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
titanic_dataframe["sex"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
best_seller_dataframe = pd.read_csv("1.section data/bestsellers.csv")

# %%
best_seller_dataframe
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
print(best_seller_dataframe["User Rating"])
# Out:
# 0      4.7
# 1      4.6
# 2      4.7
# 3      4.7
# 4      4.8
#       ...
# 545    4.9
# 546    4.7
# 547    4.7
# 548    4.7
# 549    4.7
# Name: User Rating, Length: 550, dtype: float64

# %%
print(best_seller_dataframe["Author"].head(n=8))
# Out:
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# 5         George R. R. Martin
# 6         George R. R. Martin
# 7                 Amor Towles
# Name: Author, dtype: object

# %%
print(best_seller_dataframe.columns)
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
print(best_seller_dataframe["Genre"].unique())
# Out:
# ['Non Fiction' 'Fiction']

# %%
print(best_seller_dataframe["Author"].nunique())
# Out:
# 248

# %%
print(best_seller_dataframe["Price"].mean())
# Out:
# 13.1

# %%
print(best_seller_dataframe["Price"])
# Out:
# 0       8
# 1      22
# 2      15
# 3       6
# 4      12
#        ..
# 545     8
# 546     8
# 547     8
# 548     8
# 549     8
# Name: Price, Length: 550, dtype: int64

# %%
print(best_seller_dataframe["Price"].nlargest(n=10))
# Out:
# 69     105
# 70     105
# 473     82
# 151     54
# 346     53
# 159     52
# 271     46
# 272     46
# 273     46
# 274     46
# Name: Price, dtype: int64

# %%
print(best_seller_dataframe["Name"].value_counts().head(3))
# Out:
# Publication Manual of the American Psychological Association, 6th Edition    10
# StrengthsFinder 2.0                                                           9
# Oh, the Places You'll Go!                                                     8
# Name: Name, dtype: int64

# %%
best_seller_new_dataframe = best_seller_dataframe[["Author", "User Rating"]]

# %%
best_seller_new_dataframe
# Out:
#                        Author  User Rating
# 0                    JJ Smith          4.7
# 1                Stephen King          4.6
# 2          Jordan B. Peterson          4.7
# 3               George Orwell          4.7
# 4    National Geographic Kids          4.8
# ..                        ...          ...
# 545               Jeff Kinney          4.9
# 546               Jen Sincero          4.7
# 547               Jen Sincero          4.7
# 548               Jen Sincero          4.7
# 549               Jen Sincero          4.7
#
# [550 rows x 2 columns]

# %%
best_seller_new_dataframe.value_counts()
# Out:
# Author                              User Rating
# Jeff Kinney                         4.8            10
# American Psychological Association  4.5            10
# Gallup                              4.0             9
# Rick Riordan                        4.8             9
# Dr. Seuss                           4.9             8
#                                                    ..
# Ken Follett                         4.5             1
# Kevin Kwan                          4.3             1
# Khaled Hosseini                     4.3             1
# DK                                  4.5             1
# Jeff Kinney                         4.9             1
# Length: 301, dtype: int64

# %%
best_seller_dataframe["Genre"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Genre'>

# %%
best_seller_dataframe["Author"].value_counts().head(n=10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
best_seller_dataframe["Reviews"].value
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...
