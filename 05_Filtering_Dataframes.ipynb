# %%
import pandas as pd
houses_dataframe = pd.read_csv("1.section data/kc_house_data.csv")
titanic_dataframe = pd.read_csv("1.section data/titanic.csv")
netflix_dataframe = pd.read_csv("1.section data/netflix_titles.csv", sep = "|", index_col = 0)

# %%
titanic_five = titanic_dataframe.head(n=5)

# %%
titanic_five
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic_five["sex"] == "female"
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
titanic_five[titanic_five["sex"] == "female"] # Accessing rows based on some conditions
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
#people who passed away
titanic_five[titanic_five["survived"] == 0]
# Out:
#    pclass  survived                                             name     sex  \
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket    fare    cabin embarked boat body  \
# 2   2      1      2  113781  151.55  C22 C26        S    ?    ?
# 3  30      1      2  113781  151.55  C22 C26        S    ?  135
# 4  25      1      2  113781  151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic_dataframe[titanic_dataframe["survived"] == 1]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked   boat  \
# ...

# %%
titanic_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
titanic_dataframe[titanic_dataframe["age"] == "18"]
# Out:
#       pclass  survived                                               name  \
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 198        1         1  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...
# 228        1         0         Penasco y Castellana, Mr. Victor de Satode
# 250        1         1                         Ryerson, Miss. Emily Borie
# 270        1         1     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 289        1         1                                Taussig, Miss. Ruth
# 326        2         0                         Andrew, Mr. Edgardo Samuel
# 331        2         0                           Bailey, Mr. Percy Andrew
# 386        2         0                          Davies, Mr. Charles Henry
# 394        2         0                                Dibden, Mr. William
# 395        2         1                                Doling, Miss. Elsie
# 405        2         0                          Fahlstrom, Mr. Arne Jonas
# ...

# %%
#finding passengers whose pclass is either 2 or 3
titanic_dataframe[titanic_dataframe["pclass"] != 1]["pclass"].value_counts()
# 277 people in class 2 and 709 people in class 3
# Out:
# 3    709
# 2    277
# Name: pclass, dtype: int64

# %%
houses_dataframe
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
# find houses greater than 5 million
houses_dataframe[houses_dataframe["price"] > 5000000]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1164         8010     45517     2.0           1     4  ...     12        5990
# 1315         7390     24829     2.0           1     4  ...     12        5000
# 1448         8000     23985     2.0           0     4  ...     12        6720
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
# find houses with bedroom > 10
houses_dataframe[houses_dataframe["bedrooms"] > 10]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000  520000.0        11       3.00
# 15870  2402100895  20140625T000000  640000.0        33       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# 15870        1040            580      1947             0    98103  47.6878
#
#           long  sqft_living15  sqft_lot15
# 8757  -122.363           1420        4960
# 15870 -122.331           1330        4700
#
# [2 rows x 21 columns]

# %%
#find houses with square_ft living < 1000

houses_dataframe[houses_dataframe['sqft_living'] < 1000]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 46     8945200830  20150325T000000  210490.0         3       1.00
# 84     1133000671  20140602T000000  315000.0         3       1.00
# 117    4060000240  20140623T000000  205425.0         2       1.00
# 122    3626039187  20150406T000000  395000.0         2       1.00
# ...           ...              ...       ...       ...        ...
# 21489  6021503707  20150120T000000  352500.0         2       2.50
# 21538  1865400076  20140509T000000  324000.0         3       2.25
# 21569  6021503705  20141015T000000  329000.0         2       2.50
# 21578   567000385  20140623T000000  362500.0         2       1.50
# 21583  2025049203  20140610T000000  399950.0         2       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2              770     10000     1.0           0     0  ...      6
# ...

# %%
houses_dataframe[houses_dataframe["bedrooms"].between(5, 7)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 14     1175000570  20150312T000000   530000.0         5       2.00
# 22     7137970340  20140703T000000   285000.0         5       2.50
# 42     7203220400  20140707T000000   861990.0         5       2.75
# 51     7231300125  20150217T000000   345000.0         5       2.50
# 54     4217401195  20150303T000000   920000.0         5       2.25
# ...           ...              ...        ...       ...        ...
# 21564  7168100015  20141009T000000   579950.0         5       2.75
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
# 21593  8672200110  20150317T000000  1088000.0         5       3.75
# 21596  7502800100  20140813T000000   679950.0         5       2.75
# 21600   249000205  20141015T000000  1537000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 14            1810      4850     1.5           0     0  ...      7
# ...

# %%
houses_dataframe[houses_dataframe["grade"].between(11, 13)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 70     1525059190  20140912T000000  1040000.0         5       3.25
# 153    7855801670  20150401T000000  2250000.0         4       3.25
# 269    7960900060  20150504T000000  2900000.0         4       3.25
# 270    4054500390  20141007T000000  1365000.0         4       4.75
# ...           ...              ...        ...       ...        ...
# 21532   324069112  20140617T000000  1325000.0         4       4.00
# 21548  8835770330  20140819T000000  1057000.0         2       1.50
# 21551  1561750040  20141224T000000  1375000.0         5       4.50
# 21590  7430200100  20140514T000000  1222500.0         4       3.50
# 21600   249000205  20141015T000000  1537000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 5             5420    101930     1.0           0     0  ...     11
# ...

# %%
netflix_dataframe
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_dataframe[netflix_dataframe["country"].isin(["India", "Japan"])]
# Out:
#      show_id     type                                              title  \
# 4         s5  TV Show                                       Kota Factory
# 24       s25    Movie                                              Jeans
# 39       s40  TV Show                                       Chhota Bheem
# 50       s51  TV Show                                      Dharmakshetra
# 51       s52    Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# ...      ...      ...                                                ...
# 8773   s8774    Movie                                Yanda Kartavya Aahe
# 8775   s8776  TV Show                                    Yeh Meri Family
# 8798   s8799    Movie                                           Zed Plus
# 8799   s8800    Movie                                              Zenda
# 8806   s8807    Movie                                             Zubaan
#
#                      director  \
# 4                         NaN
# ...

# %%
netflix_dataframe[netflix_dataframe["rating"].isin(["TV-MA", "R"])]
# Out:
#      show_id     type                  title                 director  \
# 1         s2  TV Show          Blood & Water                      NaN
# 2         s3  TV Show              Ganglands          Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans                      NaN
# 4         s5  TV Show           Kota Factory                      NaN
# 5         s6  TV Show          Midnight Mass            Mike Flanagan
# ...      ...      ...                    ...                      ...
# 8791   s8792    Movie            Young Adult            Jason Reitman
# 8798   s8799    Movie               Zed Plus  Chandra Prakash Dwivedi
# 8801   s8802    Movie                Zinzana          Majid Al Ansari
# 8802   s8803    Movie                 Zodiac            David Fincher
# 8804   s8805    Movie             Zombieland          Ruben Fleischer
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
titanic_dataframe
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
women = titanic_dataframe['sex'] == "female"
died = titanic_dataframe["survived"] == 0

# %%
titanic_dataframe[women & died]
# Out:
#       pclass  survived                                               name  \
# 2          1         0                       Allison, Miss. Helen Loraine
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 105        1         0                           Evans, Miss. Edith Corse
# 169        1         0                         Isham, Miss. Ann Elizabeth
# 286        1         0             Straus, Mrs. Isidor (Rosalie Ida Blun)
# ...      ...       ...                                                ...
# 1273       3         0                 Vander Planke, Miss. Augusta Maria
# 1276       3         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
houses_dataframe
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses_dataframe[(houses_dataframe["waterfront"] == 1) & (houses_dataframe["price"] < 500000)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 264    2123039032  20141027T000000  369900.0         1       0.75
# 1168   3523029041  20141009T000000  290000.0         2       0.75
# 1949   1922039062  20150420T000000  480000.0         2       1.50
# 3829   8550001515  20141001T000000  429592.0         2       2.75
# 6102    222029026  20140917T000000  340000.0         2       0.75
# 8277    221029019  20150428T000000  400000.0         3       2.50
# 8450    121039042  20150313T000000  425000.0         3       2.75
# 11556  2013802030  20140911T000000  357000.0         3       2.00
# 14827  2423029009  20140617T000000  465000.0         2       2.00
# 16570  2923039243  20141113T000000  340000.0         4       1.00
# 18275  2781600195  20141117T000000  285000.0         1       1.00
# 18848  7631800110  20140918T000000  380000.0         3       2.50
# 19002  5216200090  20140616T000000  385000.0         2       1.00
#
# ...

# %%
houses_dataframe[(houses_dataframe["view"] == 4) & (houses_dataframe["grade"] > 10)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 540     622049114  20150218T000000  2125000.0         3       2.50
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# 2444   7524900003  20141210T000000  3278000.0         2       1.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 2713   7851980260  20140730T000000  1110000.0         5       3.50
# 3157   1827200265  20140911T000000  1899000.0         2       2.75
# 3586   9272200090  20150204T000000  1598890.0         4       4.50
# 4013    724069059  20140509T000000  2400000.0         3       2.25
# 4190   2303900090  20140729T000000  2880500.0         4       2.50
# 4406   3505100756  20141106T000000  2050000.0         4       3.00
# ...

# %%
houses_dataframe[(houses_dataframe["view"] == 4) & (houses_dataframe["grade"] >10) & (houses_dataframe["sqft_living"] <= 3100)]
# Out:
#              id             date      price  bedrooms  bathrooms  sqft_living  \
# 4013  724069059  20140509T000000  2400000.0         3       2.25         3000
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 4013     11665     1.5           1     4  ...     11        3000
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 4013              0      2001             0    98075  47.5884 -122.086
#
#       sqft_living15  sqft_lot15
# 4013           3000       15959
#
# [1 rows x 21 columns]

# %%
houses_dataframe[(houses_dataframe["yr_built"] >= 2010) | (houses_dataframe["yr_renovated"] >= 2010)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 42     7203220400  20140707T000000   861990.0         5       2.75
# 63     9528102996  20141207T000000   549000.0         3       1.75
# 103    2450000295  20141007T000000  1088000.0         3       2.50
# 116    3362400431  20140626T000000   518500.0         3       3.50
# 133    8929000270  20140512T000000   453246.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 21598  8956200760  20141013T000000   541800.0         4       2.50
# 21602   844000965  20140626T000000   224000.0         3       1.75
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 42            3595      5639     2.0           0     0  ...      9
# ...

# %%
netflix_dataframe
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_dataframe[(netflix_dataframe["director"] == "David Fincher") | (netflix_dataframe["director"] == "Peter Hewitt")]
# Out:
#      show_id   type                            title       director  \
# 600     s601  Movie                         The Game  David Fincher
# 1595   s1596  Movie                             MANK  David Fincher
# 7701   s7702  Movie                       Panic Room  David Fincher
# 8320   s8321  Movie  The Girl with the Dragon Tattoo  David Fincher
# 8511   s8512  Movie               The Social Network  David Fincher
# 8802   s8803  Movie                           Zodiac  David Fincher
# 8805   s8806  Movie                             Zoom   Peter Hewitt
#
#                                                    cast  \
# 600   Michael Douglas, Sean Penn, Deborah Kara Unger...
# 1595  Gary Oldman, Amanda Seyfried, Charles Dance, L...
# 7701  Jodie Foster, Forest Whitaker, Dwight Yoakam, ...
# 8320  Daniel Craig, Rooney Mara, Christopher Plummer...
# 8511  Jesse Eisenberg, Andrew Garfield, Justin Timbe...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# ...

# %%
netflix_dataframe[((netflix_dataframe["director"] == "David Fincher") | (netflix_dataframe["director"] == "Peter Hewitt"))\
                 & (netflix_dataframe["release_year"] > 2010)]
# Out:
#      show_id   type                            title       director  \
# 1595   s1596  Movie                             MANK  David Fincher
# 8320   s8321  Movie  The Girl with the Dragon Tattoo  David Fincher
#
#                                                    cast  \
# 1595  Gary Oldman, Amanda Seyfried, Charles Dance, L...
# 8320  Daniel Craig, Rooney Mara, Christopher Plummer...
#
#                             country        date_added  release_year rating  \
# 1595                  United States  December 4, 2020          2020      R
# 8320  United States, Sweden, Norway   January 5, 2021          2011      R
#
#      duration                   listed_in  \
# 1595  133 min  Dramas, Independent Movies
# 8320  158 min           Dramas, Thrillers
#
#                                             description
# 1595  1930s Hollywood is reevaluated through the eye...
# 8320  When a young computer hacker is tasked with in...

# %%
netflix_dataframe
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_dataframe[(netflix_dataframe["director"].isna()) & (netflix_dataframe["cast"].isna())]
# Out:
#      show_id     type                                title director cast  \
# 3         s4  TV Show                Jailbirds New Orleans      NaN  NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN  NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN  NaN
# 66       s67  TV Show        Raja Rasoi Aur Anya Kahaniyan      NaN  NaN
# 69       s70  TV Show       Stories by Rabindranath Tagore      NaN  NaN
# ...      ...      ...                                  ...      ...  ...
# 8605   s8606  TV Show                            Top Grier      NaN  NaN
# 8609   s8610  TV Show                               Towies      NaN  NaN
# 8700   s8701  TV Show                    Wartime Portraits      NaN  NaN
# 8755   s8756  TV Show                    Women Behind Bars      NaN  NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN  NaN
#
#             country          date_added  release_year rating   duration  \
# ...

# %%
netflix_dataframe[netflix_dataframe["director"].notna()]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
houses_dataframe[houses_dataframe["price"]>= 5000000]["zipcode"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
bestsellers_dataframe = pd.read_csv(filepath_or_buffer="1.section data/bestsellers.csv")

# %%
bestsellers_dataframe
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
bestsellers_dataframe[bestsellers_dataframe["Author"] == "Pete Souza"]
# Out:
#                             Name      Author  User Rating  Reviews  Price  \
# 244  Obama: An Intimate Portrait  Pete Souza          4.9     3192     22
#
#      Year        Genre
# 244  2017  Non Fiction

# %%
bestsellers_dataframe[bestsellers_dataframe["Price"] < 10]
# Out:
#                                                   Name           Author  \
# 0                        10-Day Green Smoothie Cleanse         JJ Smith
# 3                               1984 (Signet Classics)    George Orwell
# 8        A Higher Loyalty: Truth, Lies, and Leadership      James Comey
# 9                            A Man Called Ove: A Novel  Fredrik Backman
# 10                           A Man Called Ove: A Novel  Fredrik Backman
# ..                                                 ...              ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
bestsellers_dataframe[(bestsellers_dataframe["Price"] >= 50) & (bestsellers_dataframe["Price"] <= 60)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 159         Harry Potter Paperback Box Set (Books 1-7)       J. K. Rowling
# 346  The Book of Basketball: The NBA According to T...        Bill Simmons
#
#      User Rating  Reviews  Price  Year        Genre
# 151          4.9     5867     54  2016  Non Fiction
# 159          4.8    13471     52  2016      Fiction
# 346          4.7      858     53  2009  Non Fiction

# %%
bestsellers_dataframe[bestsellers_dataframe["Price"].between(left=50, right=60)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 159         Harry Potter Paperback Box Set (Books 1-7)       J. K. Rowling
# 346  The Book of Basketball: The NBA According to T...        Bill Simmons
#
#      User Rating  Reviews  Price  Year        Genre
# 151          4.9     5867     54  2016  Non Fiction
# 159          4.8    13471     52  2016      Fiction
# 346          4.7      858     53  2009  Non Fiction

# %%
bestsellers_dataframe[(bestsellers_dataframe["Author"] == "Kristin Hannah") | (bestsellers_dataframe["Author"] == "Andy Weir") |\
                     (bestsellers_dataframe["Author"] == "Delia Owens")]
# Out:
#                          Name          Author  User Rating  Reviews  Price  \
# 433               The Martian       Andy Weir          4.7    39459      9
# 437  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 438  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 534   Where the Crawdads Sing     Delia Owens          4.8    87841     15
#
#      Year    Genre
# 433  2015  Fiction
# 437  2015  Fiction
# 438  2016  Fiction
# 534  2019  Fiction

# %%
bestsellers_dataframe[(bestsellers_dataframe["Genre"] == "Non Fiction") & (bestsellers_dataframe["User Rating"] == 4.9)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 174                       Humans of New York : Stories     Brandon Stanton
# 187  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 188  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 189  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 190  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 191  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 192  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 244                        Obama: An Intimate Portrait          Pete Souza
# 431                                 The Magnolia Story         Chip Gaines
# 521                             Unfreedom of the Press       Mark R. Levin
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
bestsellers_dataframe["User Rating"].value_counts()
# Out:
# 4.8    127
# 4.7    108
# 4.6    105
# 4.5     60
# 4.9     52
# 4.4     38
# 4.3     25
# 4.0     14
# 4.2      8
# 4.1      6
# 3.9      3
# 3.8      2
# 3.6      1
# 3.3      1
# Name: User Rating, dtype: int64

# %%
bestsellers_dataframe[(bestsellers_dataframe["User Rating"] == 3.3) & (bestsellers_dataframe["Genre"] == "Fiction")]
# Out:
#                    Name        Author  User Rating  Reviews  Price  Year  \
# 353  The Casual Vacancy  J.K. Rowling          3.3     9372     12  2012
#
#        Genre
# 353  Fiction

# %%
bestsellers_dataframe[(bestsellers_dataframe["Year"] == 2012) & (bestsellers_dataframe["Genre"] == "Fiction")] \
.sort_values(by="Reviews", ascending=False).head(n=5)
# Out:
#                                                   Name           Author  \
# 135                                          Gone Girl    Gillian Flynn
# 365                             The Fault in Our Stars       John Green
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James
# 409                          The Hunger Games (Book 1)  Suzanne Collins
# 238                      Mockingjay (The Hunger Games)  Suzanne Collins
#
#      User Rating  Reviews  Price  Year    Genre
# 135          4.0    57271     10  2012  Fiction
# 365          4.7    50482     13  2012  Fiction
# 106          3.8    47265     14  2012  Fiction
# 409          4.7    32122      8  2012  Fiction
# 238          4.5    26741      8  2012  Fiction

# %%
bestsellers_dataframe[bestsellers_dataframe["User Rating"] < 4.5]["Author"].value_counts().head(n=5).plot(kind="bar")
# Out:
# <AxesSubplot:>
