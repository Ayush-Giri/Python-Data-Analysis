# %%
import pandas as pd
houses_dataframe = pd.read_csv(filepath_or_buffer = "1.section data/kc_house_data.csv")
titanic_dataframe = pd.read_csv(filepath_or_buffer = "1.section data/titanic.csv")
netflix_dataframe = pd.read_csv(filepath_or_buffer = "1.section data/netflix_titles.csv", sep="|", index_col=0)
bitcoin_dataframe = pd.read_csv(filepath_or_buffer = "1.section data/coin_Bitcoin.csv")
countries_dataframe = pd.read_csv(filepath_or_buffer = "1.section data/world-happiness-report-2021.csv")

# %%
bitcoin_dataframe
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
# Dropping columns from a dataframe
bitcoin_dataframe.drop(labels=["Name", "Symbol"], axis=1)
# Out:
#        SNo                 Date          High           Low          Open  \
# 0        1  2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1        2  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2        3  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3        4  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4        5  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...    ...                  ...           ...           ...           ...
# 2986  2987  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2988  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2989  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2990  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2991  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# ...

# %%
bitcoin_dataframe.drop(labels=["SNo", "Name", "Symbol"], axis=1)
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
bitcoin_dataframe.drop(columns=["SNo", "Name", "Symbol"])
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
bitcoin_dataframe[["High", "Low"]]
# Out:
#               High           Low
# 0       147.488007    134.000000
# 1       146.929993    134.050003
# 2       139.889999    107.720001
# 3       125.599998     92.281898
# 4       108.127998     79.099998
# ...            ...           ...
# 2986  33939.588699  32770.680780
# 2987  34909.259899  33402.696536
# 2988  35937.567147  34396.477458
# 2989  35284.344430  33213.661034
# 2990  35038.536363  33599.916169
#
# [2991 rows x 2 columns]

# %%
countries_dataframe
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
countries_dataframe.set_index(keys="Country name", inplace=True)

# %%
countries_dataframe
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
# Dropping rows
countries_dataframe.drop(labels="Denmark", axis=0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries_dataframe.drop(labels=["Denmark", "Finland", "Iceland"], axis=0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Switzerland       Western Europe         7.571
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Switzerland                            0.036         7.643         7.500
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
countries_dataframe
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
# Dropping based on index positions
countries_dataframe.drop(countries_dataframe.index[0:3])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Iceland                                0.059         7.670         7.438
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
#Adding a new column to our dataframe by default it inserts the column to the end
titanic_dataframe["species"] = "human"

# %%
titanic_dataframe
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses_dataframe
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
# insert a new column on the desired location
houses_dataframe.insert(loc=1, column="county", value="king county")

# %%
houses_dataframe
# Out:
#                id       county             date     price  bedrooms  \
# 0      7129300520  king county  20141013T000000  221900.0         3
# 1      6414100192  king county  20141209T000000  538000.0         3
# 2      5631500400  king county  20150225T000000  180000.0         2
# 3      2487200875  king county  20141209T000000  604000.0         4
# 4      1954400510  king county  20150218T000000  510000.0         3
# ...           ...          ...              ...       ...       ...
# 21608   263000018  king county  20140521T000000  360000.0         3
# 21609  6600060120  king county  20150223T000000  400000.0         4
# 21610  1523300141  king county  20140623T000000  402101.0         2
# 21611   291310100  king county  20150116T000000  400000.0         3
# 21612  1523300157  king county  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# 0           1.00         1180      5650     1.0           0  ...      7
# ...

# %%
titanic_dataframe.drop(labels="species", axis=1, inplace=True)

# %%
titanic_dataframe
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# Adding dynamic values to the column
titanic_dataframe.insert(loc=7, column="num relatives", value=titanic_dataframe["sibsp"] + titanic_dataframe["parch"])

# %%
titanic_dataframe
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  num relatives  ticket      fare    cabin  \
# ...

# %%
titanic_dataframe.sort_values(by="num relatives",ascending=False)
# Out:
#       pclass  survived                                    name     sex age  \
# 1177       3         0                     Sage, Mr. Frederick    male   ?
# 1179       3         0                   Sage, Mr. John George    male   ?
# 1173       3         0            Sage, Miss. Constance Gladys  female   ?
# 1170       3         0              Sage, Master. Thomas Henry    male   ?
# 1172       3         0                         Sage, Miss. Ada  female   ?
# ...      ...       ...                                     ...     ...  ..
# 598        2         1                    Wright, Miss. Marion  female  26
# 599        2         0  Yrois, Miss. Henriette ('Mrs Harbeck')  female  24
# 600        3         0                     Abbing, Mr. Anthony    male  42
# 604        3         1             Abelseth, Miss. Karen Marie  female  16
# 1308       3         0                      Zimmerman, Mr. Leo    male  29
#
# ...

# %%
titanic_dataframe[titanic_dataframe["survived"] == 1].sort_values(by="num relatives", ascending=False)
# Out:
#      pclass  survived                                               name  \
# 641       3         1                  Asplund, Master. Edvin Rojj Felix
# 625       3         1                    Andersson, Miss. Erna Alexandra
# 646       3         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 643       3         1                     Asplund, Miss. Lillian Gertrud
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# ..      ...       ...                                                ...
# 597       2         1                       Williams, Mr. Charles Eugene
# 598       2         1                               Wright, Miss. Marion
# 604       3         1                        Abelseth, Miss. Karen Marie
# 605       3         1                      Abelseth, Mr. Olaus Jorgensen
# 0         1         1                      Allen, Miss. Elisabeth Walton
#
#         sex age  sibsp  parch  num relatives   ticket      fare        cabin  \
# ...

# %%
titanic_dataframe[titanic_dataframe["num relatives"] == 0]["pclass"].value_counts()
# Out:
# 3    472
# 1    160
# 2    158
# Name: pclass, dtype: int64

# %%
houses_dataframe
# Out:
#                id       county             date     price  bedrooms  \
# 0      7129300520  king county  20141013T000000  221900.0         3
# 1      6414100192  king county  20141209T000000  538000.0         3
# 2      5631500400  king county  20150225T000000  180000.0         2
# 3      2487200875  king county  20141209T000000  604000.0         4
# 4      1954400510  king county  20150218T000000  510000.0         3
# ...           ...          ...              ...       ...       ...
# 21608   263000018  king county  20140521T000000  360000.0         3
# 21609  6600060120  king county  20150223T000000  400000.0         4
# 21610  1523300141  king county  20140623T000000  402101.0         2
# 21611   291310100  king county  20150116T000000  400000.0         3
# 21612  1523300157  king county  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# 0           1.00         1180      5650     1.0           0  ...      7
# ...

# %%
houses_dataframe
# Out:
#                id       county             date     price  bedrooms  \
# 0      7129300520  king county  20141013T000000  221900.0         3
# 1      6414100192  king county  20141209T000000  538000.0         3
# 2      5631500400  king county  20150225T000000  180000.0         2
# 3      2487200875  king county  20141209T000000  604000.0         4
# 4      1954400510  king county  20150218T000000  510000.0         3
# ...           ...          ...              ...       ...       ...
# 21608   263000018  king county  20140521T000000  360000.0         3
# 21609  6600060120  king county  20150223T000000  400000.0         4
# 21610  1523300141  king county  20140623T000000  402101.0         2
# 21611   291310100  king county  20150116T000000  400000.0         3
# 21612  1523300157  king county  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# 0           1.00         1180      5650     1.0           0  ...      7
# ...

# %%
price_per_square_foot_living = houses_dataframe["price"] / houses_dataframe["sqft_living"]
price_per_square_foot_living
# Out:
# 0        188.050847
# 1        209.338521
# 2        233.766234
# 3        308.163265
# 4        303.571429
#             ...
# 21608    235.294118
# 21609    173.160173
# 21610    394.216667
# 21611    250.000000
# 21612    318.627451
# Length: 21613, dtype: float64

# %%
houses_dataframe.insert(loc=4, column="price_per_sqft_living", value=price_per_square_foot_living)

# %%
houses_dataframe
# Out:
#                id       county             date     price  \
# 0      7129300520  king county  20141013T000000  221900.0
# 1      6414100192  king county  20141209T000000  538000.0
# 2      5631500400  king county  20150225T000000  180000.0
# 3      2487200875  king county  20141209T000000  604000.0
# 4      1954400510  king county  20150218T000000  510000.0
# ...           ...          ...              ...       ...
# 21608   263000018  king county  20140521T000000  360000.0
# 21609  6600060120  king county  20150223T000000  400000.0
# 21610  1523300141  king county  20140623T000000  402101.0
# 21611   291310100  king county  20150116T000000  400000.0
# 21612  1523300157  king county  20141015T000000  325000.0
#
#        price_per_sqft_living  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0                 188.050847         3       1.00         1180      5650
# 1                 209.338521         3       2.25         2570      7242
# ...

# %%
houses_dataframe["price_per_sqft_living"].nlargest()
# Out:
# 19336    810.138889
# 4013     800.000000
# 10446    798.122066
# 8623     792.682927
# 9314     792.105263
# Name: price_per_sqft_living, dtype: float64

# %%
bitcoin_dataframe
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
bitcoin_dataframe.set_index(keys="Date", inplace=True)

# %%
bitcoin_dataframe.drop(labels=["SNo", "Name"], axis=1, inplace=True)

# %%
bitcoin_dataframe.drop(labels="Symbol", axis=1, inplace=True)

# %%
bitcoin_dataframe
# Out:
#                              High           Low          Open         Close  \
# Date
# 2013-04-29 23:59:59    147.488007    134.000000    134.444000    144.539993
# 2013-04-30 23:59:59    146.929993    134.050003    144.000000    139.000000
# 2013-05-01 23:59:59    139.889999    107.720001    139.000000    116.989998
# 2013-05-02 23:59:59    125.599998     92.281898    116.379997    105.209999
# 2013-05-03 23:59:59    108.127998     79.099998    106.250000     97.750000
# ...                           ...           ...           ...           ...
# 2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177  33897.048590
# 2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362  34668.548402
# 2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866  35287.779766
# 2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430  33746.002456
# 2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655  34235.193451
#
#                            Volume     Marketcap
# ...

# %%
average_intraday_price = bitcoin_dataframe["Close"] - bitcoin_dataframe["Open"]

# %%
bitcoin_dataframe.insert(loc=4, column="average_intraday_price", value=average_intraday_price)

# %%
bitcoin_dataframe
# Out:
#                              High           Low          Open         Close  \
# Date
# 2013-04-29 23:59:59    147.488007    134.000000    134.444000    144.539993
# 2013-04-30 23:59:59    146.929993    134.050003    144.000000    139.000000
# 2013-05-01 23:59:59    139.889999    107.720001    139.000000    116.989998
# 2013-05-02 23:59:59    125.599998     92.281898    116.379997    105.209999
# 2013-05-03 23:59:59    108.127998     79.099998    106.250000     97.750000
# ...                           ...           ...           ...           ...
# 2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177  33897.048590
# 2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362  34668.548402
# 2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866  35287.779766
# 2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430  33746.002456
# 2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655  34235.193451
#
# ...

# %%
bitcoin_dataframe.rename(columns={"average_intraday_price": "intraday_change"}, inplace=True)

# %%
bitcoin_dataframe
# Out:
#                              High           Low          Open         Close  \
# Date
# 2013-04-29 23:59:59    147.488007    134.000000    134.444000    144.539993
# 2013-04-30 23:59:59    146.929993    134.050003    144.000000    139.000000
# 2013-05-01 23:59:59    139.889999    107.720001    139.000000    116.989998
# 2013-05-02 23:59:59    125.599998     92.281898    116.379997    105.209999
# 2013-05-03 23:59:59    108.127998     79.099998    106.250000     97.750000
# ...                           ...           ...           ...           ...
# 2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177  33897.048590
# 2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362  34668.548402
# 2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866  35287.779766
# 2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430  33746.002456
# 2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655  34235.193451
#
# ...

# %%
bitcoin_dataframe.sort_values(by="intraday_change", ascending=False)
# Out:
#                              High           Low          Open         Close  \
# Date
# 2021-02-08 23:59:59  46203.931437  38076.322807  38886.827290  46196.463719
# 2021-04-26 23:59:59  54288.002155  48852.796843  49077.792363  54021.754787
# 2021-03-01 23:59:59  49784.015290  45115.093115  45159.503053  49631.241371
# 2021-02-19 23:59:59  56113.650547  50937.275722  51675.981285  55888.133682
# 2021-04-30 23:59:59  57900.719988  53129.600877  53568.663584  57750.177346
# ...                           ...           ...           ...           ...
# 2021-04-18 23:59:59  61057.456509  52829.535926  60701.886093  56216.185002
# 2021-01-21 23:59:59  35552.679497  30250.749639  35549.397409  30825.698506
# 2021-02-23 23:59:59  54204.929756  45290.590268  54204.929756  48824.426869
# 2021-05-19 23:59:59  43546.116485  30681.496912  42944.975447  37002.440466
# 2021-05-12 23:59:59  57939.362415  49150.533875  56714.533167  49150.533875
#
# ...

# %%
biden_tweets = pd.read_csv(filepath_or_buffer = "1.section data/JoeBidenTweets.csv")

# %%
biden_tweets
# Out:
#                        id         timestamp  \
# 0               361388562  2007-10-24 22:45
# 1               543984392  2007-12-29 15:35
# 2      189287227321356289  2012-04-09 09:42
# 3      189287350034104320  2012-04-09 09:43
# 4      189339650610036736  2012-04-09 13:11
# ...                   ...               ...
# 6059  1322865972819251200  2020-11-01 11:40
# 6060  1322871257902145536  2020-11-01 12:01
# 6061  1322876039144636417  2020-11-01 12:20
# 6062  1322881072363917312  2020-11-01 12:40
# 6063  1322886357535150081  2020-11-01 13:01
#
#                                                     url  \
# 0         https://twitter.com/JoeBiden/status/361388562
# 1         https://twitter.com/JoeBiden/status/543984392
# 2     https://twitter.com/JoeBiden/status/1892872273...
# 3     https://twitter.com/JoeBiden/status/1892873500...
# 4     https://twitter.com/JoeBiden/status/1893396506...
# ...                                                 ...
# ...

# %%
biden_tweets.drop(labels="url", axis=1)
# Out:
#                        id         timestamp  \
# 0               361388562  2007-10-24 22:45
# 1               543984392  2007-12-29 15:35
# 2      189287227321356289  2012-04-09 09:42
# 3      189287350034104320  2012-04-09 09:43
# 4      189339650610036736  2012-04-09 13:11
# ...                   ...               ...
# 6059  1322865972819251200  2020-11-01 11:40
# 6060  1322871257902145536  2020-11-01 12:01
# 6061  1322876039144636417  2020-11-01 12:20
# 6062  1322881072363917312  2020-11-01 12:40
# 6063  1322886357535150081  2020-11-01 13:01
#
#                                                   tweet  replies  retweets  \
# 0     Tune in 11:30 ET tomorrow for a live webcast o...       19         5
# 1     Iowans, there's a good chance there's a Biden ...       13        16
# 2     We're excited to announce that @JoeBiden is be...       21        82
# 3     Campaign staff will run this account to keep y...      144        76
# ...

# %%
biden_tweets[biden_tweets["id"] == 361388562]
# Out:
#           id         timestamp                                            url  \
# 0  361388562  2007-10-24 22:45  https://twitter.com/JoeBiden/status/361388562
#
#                                                tweet  replies  retweets  \
# 0  Tune in 11:30 ET tomorrow for a live webcast o...       19         5
#
#    quotes  likes
# 0      17     11

# %%
biden_tweets.drop(labels=0, axis=0)
# Out:
#                        id         timestamp  \
# 1               543984392  2007-12-29 15:35
# 2      189287227321356289  2012-04-09 09:42
# 3      189287350034104320  2012-04-09 09:43
# 4      189339650610036736  2012-04-09 13:11
# 5      189343279140184065  2012-04-09 13:25
# ...                   ...               ...
# 6059  1322865972819251200  2020-11-01 11:40
# 6060  1322871257902145536  2020-11-01 12:01
# 6061  1322876039144636417  2020-11-01 12:20
# 6062  1322881072363917312  2020-11-01 12:40
# 6063  1322886357535150081  2020-11-01 13:01
#
#                                                     url  \
# 1         https://twitter.com/JoeBiden/status/543984392
# 2     https://twitter.com/JoeBiden/status/1892872273...
# 3     https://twitter.com/JoeBiden/status/1892873500...
# 4     https://twitter.com/JoeBiden/status/1893396506...
# 5     https://twitter.com/JoeBiden/status/1893432791...
# ...                                                 ...
# ...

# %%
biden_tweets["user"] = "Joe Biden"

# %%
biden_tweets
# Out:
#                        id         timestamp  \
# 0               361388562  2007-10-24 22:45
# 1               543984392  2007-12-29 15:35
# 2      189287227321356289  2012-04-09 09:42
# 3      189287350034104320  2012-04-09 09:43
# 4      189339650610036736  2012-04-09 13:11
# ...                   ...               ...
# 6059  1322865972819251200  2020-11-01 11:40
# 6060  1322871257902145536  2020-11-01 12:01
# 6061  1322876039144636417  2020-11-01 12:20
# 6062  1322881072363917312  2020-11-01 12:40
# 6063  1322886357535150081  2020-11-01 13:01
#
#                                                     url  \
# 0         https://twitter.com/JoeBiden/status/361388562
# 1         https://twitter.com/JoeBiden/status/543984392
# 2     https://twitter.com/JoeBiden/status/1892872273...
# 3     https://twitter.com/JoeBiden/status/1892873500...
# 4     https://twitter.com/JoeBiden/status/1893396506...
# ...                                                 ...
# ...

# %%
biden_tweets.set_index(keys="id", inplace=True)

# %%
biden_tweets
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
biden_tweets
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
biden_tweets.insert(loc=5, column="ratio", value=biden_tweets["replies"] / biden_tweets["retweets"])

# %%
biden_tweets
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
biden_tweets.sort_values(by="ratio", ascending=False).head(n=10)
# Out:
#                             timestamp  \
# id
# 232971730119950338   2012-08-07 22:49
# 1200882191875465216  2019-11-30 21:00
# 1150774078233387008  2019-07-15 14:28
# 1186989582182694922  2019-10-23 12:55
# 1189327302733238272  2019-10-29 23:45
# 1181979945599455232  2019-10-09 17:09
# 1141149986505330693  2019-06-19 01:05
# 1186830433985748993  2019-10-23 02:23
# 1172309499048165376  2019-09-13 00:42
# 1152313660787908610  2019-07-19 20:26
#
#                                                                    url  \
# id
# 232971730119950338   https://twitter.com/JoeBiden/status/2329717301...
# 1200882191875465216  https://twitter.com/JoeBiden/status/1200882191...
# 1150774078233387008  https://twitter.com/JoeBiden/status/1150774078...
# 1186989582182694922  https://twitter.com/JoeBiden/status/1186989582...
# 1189327302733238272  https://twitter.com/JoeBiden/status/1189327302...
# 1181979945599455232  https://twitter.com/JoeBiden/status/1181979945...
# ...

# %%
biden_tweets.insert(loc=9, column="interactions", value=biden_tweets["replies"] + biden_tweets["retweets"] + biden_tweets["quotes"] + biden_tweets["likes"])

# %%
biden_tweets[["tweet", "interactions"]].sort_values(by="interactions", ascending=False).head(n=8)
# Out:
#                                                                  tweet  \
# id
# 1311120831032909825  Donald Trump is the worst president we've ever...
# 1253751812194070529  I can’t believe I have to say this, but please...
# 1317978773707345920  Wear a mask. Wash your hands. Vote out Donald ...
# 1318170176660135936                     ...yes https://t.co/RzZ3j3zoAL
# 1312460408192724992  One month until Election Day. Let’s do this, A...
# 1314034535890378752     .@KamalaHarris, you made us all proud tonight.
# 1314031047013732352  Pitch in $5 to help this campaign fly. https:/...
# 1307491919384260609  I’m Joe Biden and I approve this message. http...
#
#                      interactions
# id
# 1311120831032909825       2293793
# 1253751812194070529       2073072
# 1317978773707345920       1612157
# 1318170176660135936       1494296
# 1312460408192724992       1323850
# 1314034535890378752       1234867
# 1314031047013732352       1208020
# 1307491919384260609       1183455
